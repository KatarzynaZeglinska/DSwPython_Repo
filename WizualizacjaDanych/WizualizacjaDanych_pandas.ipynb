# %%
#Pandas podstawy - nauka
#impotrowanie bibliotek
import pandas as pd

# %%
# wczytanie pliku w CSV (biblioteka pd) 
df = pd.read_csv(R'C:\Users\user\Desktop\StudiaPodyplomow_DataScience_Python\4Wizualizacjaieksploracjadanych\iris.csv')
# df = pd.read_csv(R'C:\Users\user\Desktop\StudiaPodyplomow_DataScience_Python\4Wizualizacjaieksploracjadanych\Efektywnosc.csv')

# wyrzuczenie danych na ekran , 5 obserwacji 
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#wczytanie pliku excel 
#pip install xlsxwriter
#pip install xlrd
df = pd.read_excel('faktury.xls', sheet_name = 'faktury')
# df.to_excel('output.xlsx',sheet_name='Sheet_name_1', engine='xlsxwriter')

# %%
df.head()
# Out:
#    Id Towaru nr faktury            NIP Data Faktury płatność       płatnik  \
# 0         47    F1/2003  558-73-64-209   2003-01-01  gotowka     PTU ELBUD
# 1         99    F1/2003  558-73-64-209   2003-01-01  gotowka     PTU ELBUD
# 2        362    F1/2004  474-629-76-54   2004-01-02  przelew  Pawel Makina
# 3        214    F1/2004  474-629-76-54   2004-01-02  przelew  Pawel Makina
# 4         91    F1/2004  474-629-76-54   2004-01-02  przelew  Pawel Makina
#
#       pesel/regon             adres     kod     miasto        telefon  \
# 0  19478-20163444  ul. Wadowicka 12  30-415     Poznan  (51)366-99-61
# 1  19478-20163444  ul. Wadowicka 12  30-415     Poznan  (51)366-99-61
# 2     32071019422   Ul. Zablocie 23  62-170  Lubliniec  (48)499-79-50
# 3     32071019422   Ul. Zablocie 23  62-170  Lubliniec  (48)499-79-50
# 4     32071019422   Ul. Zablocie 23  62-170  Lubliniec  (48)499-79-50
#
#   typ klienta  ilośc towaru  cena towaru kod towaru  \
# 0         ins             2       209.02     KT7147
# 1         ins             2       340.10     KT6415
# 2         ind             2       720.40     KT4957
# 3         ind             2       474.50     KT6219
# 4         ind             3       453.90     KT9588
#
#                                                nazwa miara  \
# 0  Gigabyte 73PVM-S2H GF7100, VGA, PCIex, DDR2-80...   szt
# 1                   1 TB Samsung SATAII 7200OBR 32MB   szt
# 2                            Samsung KOLOR CLP-350N    szt
# 3   MONITOR LCD SAMSUNG 19" SM932GW 2ms DVI panorama   szt
# 4           W ofercie takze plyty innych producentow   szt
#
#    ilość w opakowaniu  VAT  stan magazynu
# 0                   1    7             25
# 1                   1   22             19
# 2                   1   22             35
# 3                   1    7              2
# 4                   1    7             34
